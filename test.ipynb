# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb

# %%
# %sql SELECT * FROM songplays where user_id = '15' limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 4 rows affected.
# [('256', 1542194289796, 15, 'paid', None, None, '557', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  ('495', 1542840121796, 15, 'paid', None, None, '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  ('502', 1542841596796, 15, 'paid', None, None, '818', 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (32, 'Lily', 'Burns', 'F', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (92, 'Ryann', 'Smith', 'F', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free')]

# %%
# %sql SELECT s.* FROM songs s order by song_id limit 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOAOIBZ12AB01815BE', 'I Hold Your Hand In Mine [Live At Royal Albert Hall]', 'ARPBNLO1187FB3D52F', 2000, 43.36281),
#  ('SOBAYLL12A8C138AF9', 'Sono andati? Fingevo di dormire', 'ARDR4AC1187FB371A1', 0, 511.16363),
#  ('SOBBUGU12A8C13E95D', 'Setting Fire to Sleeping Giants', 'ARMAC4T1187FB3FA4C', 2004, 207.77751),
#  ('SOBBXLX12A58A79DDA', 'Erica (2005 Digital Remaster)', 'AREDBBQ1187B98AFF5', 0, 138.63138),
#  ('SOBCOSW12A8C13D398', 'Rumba De Barcelona', 'AR7SMBG1187B9B9066', 0, 218.38322)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan),
#  ('ARXR32B1187FB57099', 'Gob', '', nan, nan),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', nan, nan),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1541903636796, 2, 11, 11, 45, 2018, 6),
#  (1541903770796, 2, 11, 11, 45, 2018, 6),
#  (1541904034796, 2, 11, 11, 45, 2018, 6),
#  (1541910973796, 4, 11, 11, 45, 2018, 6),
#  (1541911006796, 4, 11, 11, 45, 2018, 6)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select * from songs join artists on songs.artist_id = artists.artist_id where artists.name = 'Frumpies'
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql select name from artists order by 1;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 69 rows affected.
# [('40 Grit',),
#  ('Adam Ant',),
#  ('Alice Stuart',),
#  ('Andy Andy',),
#  ('Backstreet Boys',),
#  ('Billie Jo Spears',),
#  ('Bitter End',),
#  ('Blingtones',),
#  ('Blue Rodeo',),
#  ('Bob Azzam',),
#  ('Bombay Rockers',),
#  ('Casual',),
#  ('Chase & Status',),
#  ('Christos Dantis',),
#  ('Clp',),
#  ('Danilo Perez',),
#  ('David Martin',),
#  ('Eddie Calvert',),
#  ('Elena',),
#  ('Faiz Ali Faiz',),
#  ('Faye Adams',),
#  ('Five Bolt Main',),
#  ('Glad',),
#  ('Gloriana',),
#  ('Gob',),
#  ('Gwen Stefani',),
#  ('Jeff And Sheri Easter',),
#  ('JennyAnyKind',),
#  ('Jimmy Wakely',),
#  ('Jinx',),
#  ('John Davis',),
#  ('John Wesley',),
#  ('Kenny G featuring Daryl Hall',),
#  ('King Curtis',),
#  ('lextrical',),
#  ('Line Renaud',),
#  ('Lionel Richie',),
#  ('Los Manolos',),
#  ('Luna Orbit Project',),
#  ('Lupe Fiasco',),
#  ('Marc Shaiman',),
#  ("Mike Jones (Featuring CJ_ Mello & Lil' Bran)",),
# ...
